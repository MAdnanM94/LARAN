# %%
# !pip install pyreadr
import pyreadr
import pandas as pd

# %%
result = pyreadr.read_r('debate_transcripts.rda')

# %%
print(result.keys())
# Out:
# odict_keys(['debate_transcripts'])

# %%
df=result["debate_transcripts"]

# %%
df.head()
# Out:
#              speaker                                               text type  \
# 0    Dorothy Ridings  Good evening from the Civic Center in Philadel...   VP
# 1     Sander Vanocur  Thank you, Dorothy. A few words about the orde...   VP
# 2        John Mashek  John Adams, our nations first vice- president,...   VP
# 3  George H. W. Bush  Well, I dont think theres a great difference, ...   VP
# 4        John Mashek  Well some Republicans have criticized Mr. Mond...   VP
#
#    election_year        date  candidate
# 0         1984.0  1984-10-11        0.0
# 1         1984.0  1984-10-11        0.0
# 2         1984.0  1984-10-11        0.0
# 3         1984.0  1984-10-11        1.0
# 4         1984.0  1984-10-11        0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19435 entries, 0 to 19434
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   speaker        19435 non-null  object
#  1   text           19435 non-null  object
#  2   type           19435 non-null  object
#  3   election_year  19435 non-null  float64
#  4   date           19435 non-null  object
#  5   candidate      19435 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 911.1+ KB

# %%
df_can = df[df['candidate']==1]
df_can.head()
# Out:
#               speaker                                               text type  \
# 3   George H. W. Bush  Well, I dont think theres a great difference, ...   VP
# 5   George H. W. Bush  I owe my president my judgment and then I owe ...   VP
# 7   Geraldine Ferraro  Well, let me first say that I wasnt born at th...   VP
# 9   Geraldine Ferraro  I dont. Let me say that Im not a believer in p...   VP
# 11  George H. W. Bush  Well, I was glad to get that vote of confidenc...   VP
#
#     election_year        date  candidate
# 3          1984.0  1984-10-11        1.0
# 5          1984.0  1984-10-11        1.0
# 7          1984.0  1984-10-11        1.0
# 9          1984.0  1984-10-11        1.0
# 11         1984.0  1984-10-11        1.0

# %%
df_can.speaker[-100:]
# Out:
# 19290    Donald Trump
# 19292    Donald Trump
# 19294    Donald Trump
# 19296    Donald Trump
# 19297    Donald Trump
#              ...
# 19428    Donald Trump
# 19429    Donald Trump
# 19431       Joe Biden
# 19432       Joe Biden
# 19434       Joe Biden
# Name: speaker, Length: 100, dtype: object

# %%
df_polls = pd.read_csv('approval_polllist.csv')

# %%
df_polls.columns
# Out:
# Index(['president', 'subgroup', 'modeldate', 'startdate', 'enddate',
#        'pollster', 'grade', 'samplesize', 'population', 'weight', 'influence',
#        'approve', 'disapprove', 'adjusted_approve', 'adjusted_disapprove',
#        'multiversions', 'tracking', 'url', 'poll_id', 'question_id',
#        'createddate', 'timestamp'],
#       dtype='object')

# %%
df_polls.modeldate.unique
# Out:
# <bound method Series.unique of 0       5/18/2022
# 1       5/18/2022
# 2       5/18/2022
# 3       5/18/2022
# 4       5/18/2022
#           ...
# 3586    5/18/2022
# 3587    5/18/2022
# 3588    5/18/2022
# 3589    5/18/2022
# 3590    5/18/2022
# Name: modeldate, Length: 3591, dtype: object>

# %%
df_p = pd.read_csv('approval_topline.csv')

# %%
df_p.head()
# Out:
#    president   subgroup  modeldate  approve_estimate  approve_hi  approve_lo  \
# 0  Joe Biden  All polls  5/18/2022         41.711315   45.409188   38.013442
# 1  Joe Biden     Adults  5/18/2022         40.930728   44.622384   37.239072
# 2  Joe Biden     Voters  5/18/2022         42.919399   46.595871   39.242926
# 3  Joe Biden  All polls  5/17/2022         41.593401   45.404702   37.782100
# 4  Joe Biden     Adults  5/17/2022         40.785904   44.596438   36.975370
#
#    disapprove_estimate  disapprove_hi  disapprove_lo             timestamp
# 0            52.582050      57.223307      47.940794  10:33:22 18 May 2022
# 1            52.197622      56.757590      47.637654  10:33:29 18 May 2022
# 2            52.723858      56.871777      48.575939  10:33:35 18 May 2022
# 3            52.805396      57.531609      48.079183  21:29:22 17 May 2022
# 4            52.530646      57.201910      47.859381  21:29:28 17 May 2022

# %%
df.to_csv('fulldf1984.csv')

# %%
df_can2 = df_can.copy()

# %%
df[df['election_year']==1964]
# Out:
# Empty DataFrame
# Columns: [speaker, text, type, election_year, date, candidate]
# Index: []

# %%
df_cansort = df_can2.sort_values('election_year')

# %%
df_cansort.to_csv('sorted_candidates.csv')

# %%
df_cansort.head()
# Out:
#             speaker                                               text  type  \
# 3146   John Kennedy  I uh – said that Ive served this country for f...  Pres
# 3108   John Kennedy  Mr. Howe, Mr. Vice President. First uh – let m...  Pres
# 3106  Richard Nixon  Mr. Howe, Senator Kennedy, my fellow Americans...  Pres
# 3104   John Kennedy                            Good evening, Mr. Howe.  Pres
# 3102  Richard Nixon                            Good evening, Mr. Howe.  Pres
#
#       election_year        date  candidate
# 3146         1960.0  1960-10-21        1.0
# 3108         1960.0  1960-10-21        1.0
# 3106         1960.0  1960-10-21        1.0
# 3104         1960.0  1960-10-21        1.0
# 3102         1960.0  1960-10-21        1.0

# %%
dfnew = pd.read_csv('sorted_candidates.csv')

# %%
dfnew.columns
# Out:
# Index(['Unnamed: 0', 'speaker', 'text', 'type', 'election_year', 'date',
#        'candidate', 'result'],
#       dtype='object')

# %%
dfnew.drop('Unnamed: 0',1)
dfnew['result']=0
dfnew.head()
# Out:
#    Unnamed: 0        speaker  \
# 0        3146   John Kennedy
# 1        3108   John Kennedy
# 2        3106  Richard Nixon
# 3        3104   John Kennedy
# 4        3102  Richard Nixon
#
#                                                 text  type  election_year  \
# 0  I uh – said that Ive served this country for f...  Pres         1960.0
# 1  Mr. Howe, Mr. Vice President. First uh – let m...  Pres         1960.0
# 2  Mr. Howe, Senator Kennedy, my fellow Americans...  Pres         1960.0
# 3                            Good evening, Mr. Howe.  Pres         1960.0
# 4                            Good evening, Mr. Howe.  Pres         1960.0
#
#          date  candidate  result
# 0  1960-10-21        1.0       0
# 1  1960-10-21        1.0       0
# 2  1960-10-21        1.0       0
# 3  1960-10-21        1.0       0
# 4  1960-10-21        1.0       0

# %%
dfnew.loc[(dfnew['speaker']=='John Kennedy') & (dfnew['election_year']=='1960'),'result']=1

# %%
dfnew.head()
# Out:
#    Unnamed: 0        speaker  \
# 0        3146   John Kennedy
# 1        3108   John Kennedy
# 2        3106  Richard Nixon
# 3        3104   John Kennedy
# 4        3102  Richard Nixon
#
#                                                 text  type  election_year  \
# 0  I uh – said that Ive served this country for f...  Pres         1960.0
# 1  Mr. Howe, Mr. Vice President. First uh – let m...  Pres         1960.0
# 2  Mr. Howe, Senator Kennedy, my fellow Americans...  Pres         1960.0
# 3                            Good evening, Mr. Howe.  Pres         1960.0
# 4                            Good evening, Mr. Howe.  Pres         1960.0
#
#          date  candidate  result
# 0  1960-10-21        1.0       0
# 1  1960-10-21        1.0       0
# 2  1960-10-21        1.0       0
# 3  1960-10-21        1.0       0
# 4  1960-10-21        1.0       0

# %% [markdown]
# # The following websites were used to fill in  the target column, results
#
# https://www.britannica.com/topic/United-States-Presidential-Election-Results-1788863
#
#  https://www.britannica.com/topic/vice-president-of-the-United-States-of-America

# %%
dfnew.loc[(dfnew['speaker']=='John Kennedy') & (dfnew['election_year']==1964.0), 'result']=1

# %%
dfnew.head()
# Out:
#    Unnamed: 0        speaker  \
# 0        3146   John Kennedy
# 1        3108   John Kennedy
# 2        3106  Richard Nixon
# 3        3104   John Kennedy
# 4        3102  Richard Nixon
#
#                                                 text  type  election_year  \
# 0  I uh – said that Ive served this country for f...  Pres         1960.0
# 1  Mr. Howe, Mr. Vice President. First uh – let m...  Pres         1960.0
# 2  Mr. Howe, Senator Kennedy, my fellow Americans...  Pres         1960.0
# 3                            Good evening, Mr. Howe.  Pres         1960.0
# 4                            Good evening, Mr. Howe.  Pres         1960.0
#
#          date  candidate  result
# 0  1960-10-21        1.0       1
# 1  1960-10-21        1.0       1
# 2  1960-10-21        1.0       0
# 3  1960-10-21        1.0       1
# 4  1960-10-21        1.0       0

# %%
dfnew.loc[(dfnew['speaker']=='Joe Biden') & (dfnew['election_year']==2020.0), 'result']=1

# %%
dfnew.tail()
# Out:
#        Unnamed: 0           speaker  \
# 11110       11901  Elizabeth Warren
# 11111       11900       Andrew Yang
# 11112       11899  Elizabeth Warren
# 11113       11940     Amy Klobuchar
# 11114       19434         Joe Biden
#
#                                                     text  type  election_year  \
# 11110                                               Yes.   Dem         2020.0
# 11111  I don't think I have much to ask forgiveness f...   Dem         2020.0
# 11112  We can do a labor action and just all go on st...   Dem         2020.0
# 11113  Well, first the economy. We know that not ever...   Dem         2020.0
# 11114                                        Thank you.   Pres         2020.0
#
#              date  candidate  result
# 11110  2019-12-19        1.0       0
# 11111  2019-12-19        1.0       0
# 11112  2019-12-19        1.0       0
# 11113  2019-06-26        1.0       0
# 11114  2020-10-22        1.0       1

# %%
dfnew.loc[(dfnew['speaker']=="Tim Kaine") & (dfnew['election_year']==2012.0)].head(50)
# Out:
# Empty DataFrame
# Columns: [speaker, text, type, election_year, date, candidate, result]
# Index: []

# %%
dfnew.head()
# Out:
#    Unnamed: 0        speaker  \
# 0        3146   John Kennedy
# 1        3108   John Kennedy
# 2        3106  Richard Nixon
# 3        3104   John Kennedy
# 4        3102  Richard Nixon
#
#                                                 text  type  election_year  \
# 0  I uh – said that Ive served this country for f...  Pres         1960.0
# 1  Mr. Howe, Mr. Vice President. First uh – let m...  Pres         1960.0
# 2  Mr. Howe, Senator Kennedy, my fellow Americans...  Pres         1960.0
# 3                            Good evening, Mr. Howe.  Pres         1960.0
# 4                            Good evening, Mr. Howe.  Pres         1960.0
#
#          date  candidate  result
# 0  1960-10-21        1.0       1
# 1  1960-10-21        1.0       1
# 2  1960-10-21        1.0       0
# 3  1960-10-21        1.0       1
# 4  1960-10-21        1.0       0

# %%
dfnew = dfnew.drop('Unnamed: 0', 1)

# %%
dfnew.loc[(dfnew['speaker']=="Barack Obama"), 'result']=1

# %%
dfnew.head()
# Out:
#          speaker                                               text  type  \
# 0   John Kennedy  I uh – said that Ive served this country for f...  Pres
# 1   John Kennedy  Mr. Howe, Mr. Vice President. First uh – let m...  Pres
# 2  Richard Nixon  Mr. Howe, Senator Kennedy, my fellow Americans...  Pres
# 3   John Kennedy                            Good evening, Mr. Howe.  Pres
# 4  Richard Nixon                            Good evening, Mr. Howe.  Pres
#
#    election_year        date  candidate  result
# 0         1960.0  1960-10-21        1.0       1
# 1         1960.0  1960-10-21        1.0       1
# 2         1960.0  1960-10-21        1.0       0
# 3         1960.0  1960-10-21        1.0       1
# 4         1960.0  1960-10-21        1.0       0

# %%
dfnew.loc[(dfnew['speaker']=="Donald Trump")&(dfnew['election_year']==2016.0), 'result']=1

# %%
dfnew.loc[(dfnew['speaker']=="Donald Trump")&(dfnew['election_year']==2016.0)]
# Out:
#            speaker                                               text  type  \
# 4315  Donald Trump  I would certainly be open to closing areas whe...   Rep
# 4316  Donald Trump  Well, look, this is so easy to answer. ISIS is...   Rep
# 4342  Donald Trump  With Jeb's attitude, we will never be great ag...   Rep
# 4345  Donald Trump  Look, look, look. We need a toughness. We need...   Rep
# 4346  Donald Trump  I know you're trying to build up your energy, ...   Rep
# ...            ...                                                ...   ...
# 6354  Donald Trump  You know, Hillary is hitting me with tremendou...  Pres
# 6355  Donald Trump  … extremely rough to Hillary, to her family, a...  Pres
# 6356  Donald Trump  … $200 million is spent, and Im either winning...  Pres
# 6358  Donald Trump  I want to make America great again. We are a n...  Pres
# 6359  Donald Trump  Look, heres the story. I want to make America ...  Pres
#
#       election_year        date  candidate  result
# ...

# %%
dfnew.loc[(dfnew['speaker']=='George W. Bush') &(dfnew['election_year']==2004.0), 'result']=1

# %%
dfnew.loc[(dfnew['speaker']=='Bill Clinton') &(dfnew['election_year']==1996.0), 'result']=1
dfnew.loc[(dfnew['speaker']=='Bill Clinton') &(dfnew['election_year']==1992.0), 'result']=1

# %% [markdown]
# #Missing entries
#
# President - 1972, 1968, 1964
#
# VP - 2008, 1964-1980

# %%
dfnew.loc[(dfnew['type']=='VP')]
# Out:
#                 speaker                                               text  \
# 345   George H. W. Bush  Well, I dont think theres a great difference, ...
# 346   Geraldine Ferraro  I just have to correct in my thirty seconds th...
# 347   Geraldine Ferraro  Let me just say that Id be happy to give the v...
# 348   George H. W. Bush  Im really a Texan. But I got one house. And un...
# 349   George H. W. Bush  What that figure – and I kind of like the way ...
# ...                 ...                                                ...
# 7139      Kamala Harris                               when your children-
# 7140      Kamala Harris   couldn't see your parents because you were af...
# 7141      Kamala Harris                   I'm referring to the president-
# 7142      Kamala Harris  Let's talk about respecting the American peopl...
# 7143      Kamala Harris  Speaking of those things that you may not want...
#
#      type  election_year        date  candidate  result
# ...

# %%
dfnew.loc[(dfnew['speaker']=='George H. W. Bush') &(dfnew['election_year']==1984.0), 'result']=1

# %%
dfnew.loc[(dfnew['speaker']=='Ronald Reagan') &(dfnew['election_year']==1984.0), 'result']=1
dfnew.loc[(dfnew['speaker']=='Ronald Reagan') &(dfnew['election_year']==1980.0), 'result']=1

# %%
dfnew.loc[(dfnew['speaker']=='Jimmy Carter') &(dfnew['election_year']==1976.0), 'result']=1

# %%
dfnew.iloc[100:120]
# Out:
#            speaker                                               text  type  \
# 100  Richard Nixon  Mr. Smith, Senator Kennedy. The things that Se...  Pres
# 101   John Kennedy  Just to uh – correct the record, Mr. Nixon sai...  Pres
# 102    Gerald Ford  Governor Carter again contradicts himself. He ...  Pres
# 103    Gerald Ford  The White House did not uh – prevent the relea...  Pres
# 104    Gerald Ford  As we have seen tonight, foreign policy and de...  Pres
# 105   Jimmy Carter  The purpose of this debate and the outcome of ...  Pres
# 106   Jimmy Carter  One of the uh – most embarrassing uh – failure...  Pres
# 107    Gerald Ford  Let me restate uh – our policy. As long as Vie...  Pres
# 108    Gerald Ford  Again Governor Carter is inaccurate. The Arab ...  Pres
# 109   Jimmy Carter  I believe that the boycott of American busines...  Pres
# 110   Jimmy Carter  Well, Im reluctant to uh comment on the recent...  Pres
# ...

# %%
dfnew.head()
# Out:
#          speaker                                               text  type  \
# 0   John Kennedy  I uh – said that Ive served this country for f...  Pres
# 1   John Kennedy  Mr. Howe, Mr. Vice President. First uh – let m...  Pres
# 2  Richard Nixon  Mr. Howe, Senator Kennedy, my fellow Americans...  Pres
# 3   John Kennedy                            Good evening, Mr. Howe.  Pres
# 4  Richard Nixon                            Good evening, Mr. Howe.  Pres
#
#    election_year        date  candidate  result
# 0         1960.0  1960-10-21        1.0       1
# 1         1960.0  1960-10-21        1.0       1
# 2         1960.0  1960-10-21        1.0       0
# 3         1960.0  1960-10-21        1.0       1
# 4         1960.0  1960-10-21        1.0       0

# %%
dfnew.to_csv('data_with_target_comp.csv')
