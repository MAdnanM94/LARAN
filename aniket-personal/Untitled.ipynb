# %%
import pandas as pd

# %%
df = pd.read_csv('data_with_target_comp.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        speaker  \
# 0           0   John Kennedy
# 1           1   John Kennedy
# 2           2  Richard Nixon
# 3           3   John Kennedy
# 4           4  Richard Nixon
#
#                                                 text  type  election_year  \
# 0  I uh – said that Ive served this country for f...  Pres         1960.0
# 1  Mr. Howe, Mr. Vice President. First uh – let m...  Pres         1960.0
# 2  Mr. Howe, Senator Kennedy, my fellow Americans...  Pres         1960.0
# 3                            Good evening, Mr. Howe.  Pres         1960.0
# 4                            Good evening, Mr. Howe.  Pres         1960.0
#
#          date  candidate  result
# 0  1960-10-21        1.0       1
# 1  1960-10-21        1.0       1
# 2  1960-10-21        1.0       0
# 3  1960-10-21        1.0       1
# 4  1960-10-21        1.0       0

# %%
df = df.drop('Unnamed: 0', 1)

# %%
df.head()
# Out:
#          speaker                                               text  type  \
# 0   John Kennedy  I uh – said that Ive served this country for f...  Pres
# 1   John Kennedy  Mr. Howe, Mr. Vice President. First uh – let m...  Pres
# 2  Richard Nixon  Mr. Howe, Senator Kennedy, my fellow Americans...  Pres
# 3   John Kennedy                            Good evening, Mr. Howe.  Pres
# 4  Richard Nixon                            Good evening, Mr. Howe.  Pres
#
#    election_year        date  candidate  result
# 0         1960.0  1960-10-21        1.0       1
# 1         1960.0  1960-10-21        1.0       1
# 2         1960.0  1960-10-21        1.0       0
# 3         1960.0  1960-10-21        1.0       1
# 4         1960.0  1960-10-21        1.0       0

# %%
df['party']='U'

# %%
df.head()
# Out:
#          speaker                                               text  type  \
# 0   John Kennedy  I uh – said that Ive served this country for f...  Pres
# 1   John Kennedy  Mr. Howe, Mr. Vice President. First uh – let m...  Pres
# 2  Richard Nixon  Mr. Howe, Senator Kennedy, my fellow Americans...  Pres
# 3   John Kennedy                            Good evening, Mr. Howe.  Pres
# 4  Richard Nixon                            Good evening, Mr. Howe.  Pres
#
#    election_year        date  candidate  result party
# 0         1960.0  1960-10-21        1.0       1     U
# 1         1960.0  1960-10-21        1.0       1     U
# 2         1960.0  1960-10-21        1.0       0     U
# 3         1960.0  1960-10-21        1.0       1     U
# 4         1960.0  1960-10-21        1.0       0     U

# %%
df.speaker.unique()
# Out:
# array(['John Kennedy', 'Richard Nixon', 'Gerald Ford', 'Jimmy Carter',
#        'Ronald Reagan', 'Walter Mondale', 'George H. W. Bush',
#        'Geraldine Ferraro', 'Michael Dukakis', 'Dan Quayle',
#        'Lloyd Bentsen', 'Bill Clinton', 'Ross Perot', 'Al Gore',
#        'James Stockdale', 'Jack Kemp', 'Bob Dole', 'George W. Bush',
#        'Joe Lieberman', 'Dick Cheney', 'John Edwards', 'John Kerry',
#        'Barack Obama', 'John McCain', 'Paul Ryan', 'Joe Biden',
#        'Mitt Romney', 'Herman Cain', 'Jon Huntsman', 'Rick Perry',
#        'Rick Santorum', 'Newt Gingrich', 'Gary Johnson', 'Ron Paul',
#        'John Kasich', 'Chris Christie', 'Rand Paul', 'Jeb Bush',
#        'Marco Rubio', 'Ted Cruz', 'Ben Carson', 'Donald Trump',
#        'Carly Fiorina', 'Scott Walker', 'Mike Huckabee', 'Mike Pence',
#        'Hillary Clinton', 'Tim Kaine', 'Bernie Sanders',
#        "Martin O'Malley", 'Jim Webb', 'Lincoln Chafee', 'Amy Klobuchar',
# ...

# %%
df.loc[(df['speaker']=='John Kennedy'), 'party']='D'

# %%
df.head()
# Out:
#          speaker                                               text  type  \
# 0   John Kennedy  I uh – said that Ive served this country for f...  Pres
# 1   John Kennedy  Mr. Howe, Mr. Vice President. First uh – let m...  Pres
# 2  Richard Nixon  Mr. Howe, Senator Kennedy, my fellow Americans...  Pres
# 3   John Kennedy                            Good evening, Mr. Howe.  Pres
# 4  Richard Nixon                            Good evening, Mr. Howe.  Pres
#
#    election_year        date  candidate  result party
# 0         1960.0  1960-10-21        1.0       1     D
# 1         1960.0  1960-10-21        1.0       1     D
# 2         1960.0  1960-10-21        1.0       0     U
# 3         1960.0  1960-10-21        1.0       1     D
# 4         1960.0  1960-10-21        1.0       0     U

# %%
df.loc[(df['speaker']=='Richard Nixon'), 'party']='R'
df.loc[(df['speaker']=='Gerald Ford'), 'party']='R'
df.loc[(df['speaker']=='Jimmy Carter'), 'party']='D'
df.loc[(df['speaker']=='Ronald Reagan'), 'party']='R'
df.loc[(df['speaker']=='Walter Mondale'), 'party']='D'
df.loc[(df['speaker']=='George H. W. Bush'), 'party']='R'
df.loc[(df['speaker']=='Geraldine Ferraro'), 'party']='D'

# %%
df.sample(50)
# Out:
#                   speaker                                               text  \
# 6878            Joe Biden  No. Look, the World Health Organization offere...
# 7334         Donald Trump                                                No.
# 7223         Donald Trump                                          Go ahead.
# 6603            Joe Biden                 Thats like saying Jack the ripper.
# 5793      Hillary Clinton                          … a very clear fact that…
# 3321        Newt Gingrich                       Okay- - those four points- -
# 10225      Bernie Sanders   I can Adam, and let me also say that in 1988 ...
# 4774       Chris Christie  Well, what it would like is, we have one of th...
# 10705    Elizabeth Warren       10 weeks ago, pay overtime, and get it done.
# 887     George H. W. Bush  I dont think thats true at all. I dont think t...
# 902          Bill Clinton  Mr. Perot, with all respect, I think it is hig...
# ...

# %%
df.speaker.unique()
# Out:
# array(['John Kennedy', 'Richard Nixon', 'Gerald Ford', 'Jimmy Carter',
#        'Ronald Reagan', 'Walter Mondale', 'George H. W. Bush',
#        'Geraldine Ferraro', 'Michael Dukakis', 'Dan Quayle',
#        'Lloyd Bentsen', 'Bill Clinton', 'Ross Perot', 'Al Gore',
#        'James Stockdale', 'Jack Kemp', 'Bob Dole', 'George W. Bush',
#        'Joe Lieberman', 'Dick Cheney', 'John Edwards', 'John Kerry',
#        'Barack Obama', 'John McCain', 'Paul Ryan', 'Joe Biden',
#        'Mitt Romney', 'Herman Cain', 'Jon Huntsman', 'Rick Perry',
#        'Rick Santorum', 'Newt Gingrich', 'Gary Johnson', 'Ron Paul',
#        'John Kasich', 'Chris Christie', 'Rand Paul', 'Jeb Bush',
#        'Marco Rubio', 'Ted Cruz', 'Ben Carson', 'Donald Trump',
#        'Carly Fiorina', 'Scott Walker', 'Mike Huckabee', 'Mike Pence',
#        'Hillary Clinton', 'Tim Kaine', 'Bernie Sanders',
#        "Martin O'Malley", 'Jim Webb', 'Lincoln Chafee', 'Amy Klobuchar',
# ...

# %%
df.loc[(df['speaker']=='Michael Dukakis'), 'party']='D'
df.loc[(df['speaker']=='Dan Quayle'), 'party']='R'
df.loc[(df['speaker']=='Lloyd Bentsen'), 'party']='D'
df.loc[(df['speaker']=='Bill Clinton'), 'party']='D'
df.loc[(df['speaker']=='Ross Perot'), 'party']='I'
df.loc[(df['speaker']=='Al Gore'), 'party']='D'
df.loc[(df['speaker']=='James Stockdale'), 'party']='I'
df.loc[(df['speaker']=='Jack Kemp'), 'party']='R'
df.loc[(df['speaker']=='Bob Dole'), 'party']='R'
df.loc[(df['speaker']=='George W. Bush'), 'party']='R'
df.loc[(df['speaker']=='Joe Lieberman'), 'party']='D'
df.loc[(df['speaker']=='Dick Cheney'), 'party']='R'
df.loc[(df['speaker']=='John Edwards'), 'party']='D'
df.loc[(df['speaker']=='John Kerry'), 'party']='D'
df.loc[(df['speaker']=='Barack Obama'), 'party']='D'
df.loc[(df['speaker']=='John McCain'), 'party']='R'
df.loc[(df['speaker']=='Paul Ryan'), 'party']='R'
df.loc[(df['speaker']=='Joe Biden'), 'party']='D'
df.loc[(df['speaker']=='Mitt Romney'), 'party']='R'
df.loc[(df['speaker']=='Herman Cain'), 'party']='R'
df.loc[(df['speaker']=='Jon Huntsman'), 'party']='R'
df.loc[(df['speaker']=='Rick Perry'), 'party']='R'
df.loc[(df['speaker']=='Rick Santorum'), 'party']='R'
df.loc[(df['speaker']=='Newt Gingrich'), 'party']='R'
df.loc[(df['speaker']=='Gary Johnson'), 'party']='Lib'

# %%
df.speaker.unique()
# Out:
# array(['John Kennedy', 'Richard Nixon', 'Gerald Ford', 'Jimmy Carter',
#        'Ronald Reagan', 'Walter Mondale', 'George H. W. Bush',
#        'Geraldine Ferraro', 'Michael Dukakis', 'Dan Quayle',
#        'Lloyd Bentsen', 'Bill Clinton', 'Ross Perot', 'Al Gore',
#        'James Stockdale', 'Jack Kemp', 'Bob Dole', 'George W. Bush',
#        'Joe Lieberman', 'Dick Cheney', 'John Edwards', 'John Kerry',
#        'Barack Obama', 'John McCain', 'Paul Ryan', 'Joe Biden',
#        'Mitt Romney', 'Herman Cain', 'Jon Huntsman', 'Rick Perry',
#        'Rick Santorum', 'Newt Gingrich', 'Gary Johnson', 'Ron Paul',
#        'John Kasich', 'Chris Christie', 'Rand Paul', 'Jeb Bush',
#        'Marco Rubio', 'Ted Cruz', 'Ben Carson', 'Donald Trump',
#        'Carly Fiorina', 'Scott Walker', 'Mike Huckabee', 'Mike Pence',
#        'Hillary Clinton', 'Tim Kaine', 'Bernie Sanders',
#        "Martin O'Malley", 'Jim Webb', 'Lincoln Chafee', 'Amy Klobuchar',
# ...

# %%
df.loc[(df['speaker']=='Ron Paul'), 'party']='Lib'
df.loc[(df['speaker']=='John Kasich'), 'party']='R'
df.loc[(df['speaker']=='Chris Christie'), 'party']='R'
df.loc[(df['speaker']=='Rand Paul'), 'party']='R'
df.loc[(df['speaker']=='Jeb Bush'), 'party']='R'
df.loc[(df['speaker']=='Marco Rubio'), 'party']='R'
df.loc[(df['speaker']=='Ted Cruz'), 'party']='R'
df.loc[(df['speaker']=='Ben Carson'), 'party']='R'
df.loc[(df['speaker']=='Donald Trump'), 'party']='R'
df.loc[(df['speaker']=='Carly Fiorina'), 'party']='R'
df.loc[(df['speaker']=='Scott Walker'), 'party']='R'
df.loc[(df['speaker']=='Mike Huckabee'), 'party']='R'
df.loc[(df['speaker']=='Mike Pence'), 'party']='R'
df.loc[(df['speaker']=='Hillary Clinton'), 'party']='D'
df.loc[(df['speaker']=='Tim Kaine'), 'party']='D'
df.loc[(df['speaker']=='Bernie Sanders'), 'party']='D'
df.loc[(df['speaker']== "Martin O'Malley"), 'party']='D'
df.loc[(df['speaker']=='Jim Webb'), 'party']='D'
df.loc[(df['speaker']=='Kamala Harris'), 'party']='D'

# %%
df.loc[(df['type']=='Dem'), 'party']='D'
df.sample(50)
df.loc[df['party']=='U']
# Out:
#             speaker                                               text type  \
# 6912  Kamala Harris  He doesn't understand what it means to be hone...   VP
# 6914  Kamala Harris  There was a team of disease experts that Presi...   VP
# 6915  Kamala Harris  So I love talking with Joe about a lot of thes...   VP
# 6916  Kamala Harris  Let's take for example, Russia. So I serve on ...   VP
# 6917  Kamala Harris  You can look at the Iran nuclear deal, which n...   VP
# ...             ...                                                ...  ...
# 7139  Kamala Harris                               when your children-    VP
# 7140  Kamala Harris   couldn't see your parents because you were af...   VP
# 7141  Kamala Harris                   I'm referring to the president-    VP
# 7142  Kamala Harris  Let's talk about respecting the American peopl...   VP
# 7143  Kamala Harris  Speaking of those things that you may not want...   VP
#
#       election_year        date  candidate  result party
# ...

# %%
df.loc[df['party']=='U']
# Out:
# Empty DataFrame
# Columns: [speaker, text, type, election_year, date, candidate, result, party]
# Index: []

# %%
df.sample(50)
# Out:
#                 speaker                                               text  \
# 6769     Bernie Sanders                                     Can I respond?
# 1111            Al Gore                                               We —
# 1692            Al Gore  High school. I mentioned before that the local...
# 8693      Julian Castro   Thank you very much. Well thats quite a lot. ...
# 3031          Joe Biden  Ninety- seven percent of the small businesses ...
# 986          Dan Quayle                     Youre going to qualify it now.
# 7322       Donald Trump                                         It's what?
# 7603       Donald Trump  Excuse me. I got rid of the individual mandate...
# 1104            Al Gore  Three weeks from today, our nation will make a...
# 3879        Mitt Romney                       … if — if youre… (CROSSTALK)
# 7119       Donald Trump    they cheat. They cheat. Hey, they found ball...
# ...

# %%
df.to_csv('finaldata_party.csv')
